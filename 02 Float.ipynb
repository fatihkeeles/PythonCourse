# %%
x = 5
# Bu bir integer(TAM SAYI)'dır.

# %%
y = 2.1
#Bu bir float(ONDALIKLI SAYI)'dır

# %%
type(x) # Bu fonksiyon sayesinde veri türünü öğrenebilrsiniz !
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
a = 10/5

# %%
a
# Out:
# 2.0

# %%
x = 5.0

# %%
type(x)
# Out:
# float

# %%
 a = 10//5 #TABAN BÖLME İŞLEMİYLE BANA DEĞERİ İNT OLARAK DÖNDÜRECEK

# %%
a
# Out:
# 2

# %%
type(a)
# Out:
# int
