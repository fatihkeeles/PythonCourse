# %%
a = input("Buraya Bişeyler yaz : ")
# Out:
# Buraya Bişeyler yaz : Fatih keleş ile python dersleri

# %%
a
# Out:
# 'Fatih keleş ile python dersleri'

# %%
print("3 Tane Sayıyı toplama programı")
a = input("Sayı 1 giriniz :")
b = input("Sayı 2 giriniz :")
c = input("Sayı 3 giriniz :")

print("Sayıların toplamı : ",a+b+c)
# Out:
# 3 Tane Sayıyı toplama programı
# Sayı 1 giriniz :2
# Sayı 2 giriniz :3
# Sayı 3 giriniz :4
# Sayıların toplamı :  234

# %%
print("3 Tane Sayıyı toplama programı")
a = input("Sayı 1 giriniz :")
b = input("Sayı 2 giriniz :")
c = input("Sayı 3 giriniz :")

print("Sayıların toplamı : ",a+b+c)
# Out:
# 3 Tane Sayıyı toplama programı
# Sayı 1 giriniz :fa
# Sayı 2 giriniz :ti
# Sayı 3 giriniz :h
# Sayıların toplamı :  fatih

# %%
print("3 Tane Sayıyı toplama programı")
a = input("Sayı 1 giriniz :")
b = input("Sayı 2 giriniz :")
c = input("Sayı 3 giriniz :")

print("Sayıların toplamı",int(a)+int(b)+int(c))
# Out:
# 3 Tane Sayıyı toplama programı
# Sayı 1 giriniz :2
# Sayı 2 giriniz :3
# Sayı 3 giriniz :4
# Sayıların toplamı 9
