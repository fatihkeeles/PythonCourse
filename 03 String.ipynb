# %%
f = 'fatih keleş'

# %%
f
# Out:
# 'fatih keleş'

# %%
print(f)
# Out:
# fatih keleş

# %%
f[0]
# Out:
# 'f'

# %%
f[3]
# Out:
# 'i'

# %%
f[1:4]
# Out:
# 'ati'

# %%
f[-1]
# Out:
# 'ş'

# %%
f[-3]
# Out:
# 'l'

# %%
f[:]
# Out:
# 'fatih keleş'

# %%
len(f)
# Out:
# 11

# %%
k = 'fatih keleş ile python dersleri'

# %%
len(k)
# Out:
# 31
